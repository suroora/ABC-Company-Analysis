# %% [markdown]
# <h1><center>PROJECT MODULE-2</center></h1>

# %% [markdown]
# ## Step : 0 - Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel(r"1 - Learning Path\ABC company analysis\ABC-Company-Analysis\ABC_Company.xlsx")

# %%
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
df.shape
# Out:
# (458, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ## step: 1 - Preprocessing

# %%
# All data in the "height" column by replacing it with random numbers between 150 and 200.
df['Height'] = np.random.randint(150,181, size=len(df))

# %%
df["Height"]
# Out:
# 0      154
# 1      166
# 2      159
# 3      180
# 4      164
#       ...
# 453    174
# 454    151
# 455    173
# 456    161
# 457    153
# Name: Height, Length: 458, dtype: int32

# %%
# ensure other numerical columns data consistency and integrity
df.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  165.013100  221.543668  4.833970e+06
# std     15.966837    4.400128    8.874018   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  158.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  164.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  173.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  180.000000  307.000000  2.500000e+07

# %%
#ensure age colomn data consistency and integrity
df["Age"] = pd.to_numeric(df["Age"] , errors="coerce")
df["Age"].describe()
# Out:
# count    458.000000
# mean      26.934498
# std        4.400128
# min       19.000000
# 25%       24.000000
# 50%       26.000000
# 75%       30.000000
# max       40.000000
# Name: Age, dtype: float64

# %%
#ensure salary columns data consistency and integrity
df["Salary"] = pd.to_numeric(df["Salary"] , errors="coerce")
df["Salary"].describe()
# Out:
# count    4.470000e+02
# mean     4.833970e+06
# std      5.226620e+06
# min      3.088800e+04
# 25%      1.025210e+06
# 50%      2.836186e+06
# 75%      6.500000e+06
# max      2.500000e+07
# Name: Salary, dtype: float64

# %%
# Final quick integrity check
df.info()
df.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    int32
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int32(1), int64(3), object(4)
# memory usage: 30.5+ KB
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ### Save the cleaned file for Analaysis and Visualisation

# %%
df.to_csv(r"1 - Learning Path\ABC company analysis\ABC-Company-Analysis\ABC_Company_cleaned.csv", index=False)

# %%
da = pd.read_csv(r"1 - Learning Path\ABC company analysis\ABC-Company-Analysis\ABC_Company_cleaned.csv")
da.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25     154     180
# 1    Jae Crowder  Boston Celtics      99       SF   25     166     235
# 2   John Holland  Boston Celtics      30       SG   27     159     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22     180     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29     164     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %% [markdown]
# ## Step:2 - Analysis Tasks:

# %% [markdown]
# ##### Q1. Determine the distribution of employees across each team and calculate the percentage split relative to the total number of employees.

# %%
team_count = da["Team"].value_counts().sort_values(ascending=False) 
team_prec=(team_count  / len(da) * 100).round(2)
team_df = pd.DataFrame({"Count": team_count,"precentage": team_prec})
team_df
# Out:
#                         Count  precentage
# Team
# New Orleans Pelicans       19        4.15
# Memphis Grizzlies          18        3.93
# Utah Jazz                  16        3.49
# New York Knicks            16        3.49
# Milwaukee Bucks            16        3.49
# Detroit Pistons            15        3.28
# Dallas Mavericks           15        3.28
# Philadelphia 76ers         15        3.28
# Toronto Raptors            15        3.28
# Golden State Warriors      15        3.28
# Los Angeles Clippers       15        3.28
# Los Angeles Lakers         15        3.28
# Phoenix Suns               15        3.28
# Sacramento Kings           15        3.28
# Chicago Bulls              15        3.28
# Cleveland Cavaliers        15        3.28
# Boston Celtics             15        3.28
# Indiana Pacers             15        3.28
# Houston Rockets            15        3.28
# San Antonio Spurs          15        3.28
# Atlanta Hawks              15        3.28
# ...

# %%
#visualization of the team distribution using a bar chart
plt.Figure()
team_count.plot(kind='bar')
plt.title("Employee per Team")
plt.xlabel("Team"); plt.ylabel("Count")
plt.ylim(12, 20)
plt.tight_layout()
plt.show()

# %%
#Save Distributrion data to a csv file
team_df.to_csv(r"1 - Learning Path\ABC company analysis\ABC-Company-Analysis\Team_distribution.csv", index=True)

# %% [markdown]
# ##### Q2. Segregate employees based on their positions within the company.

# %%
#Segregate employees based on their positions within the company.
position_count = da["Position"].value_counts().sort_values(ascending=False)
position_count
# Out:
# Position
# SG    102
# PF    100
# PG     92
# SF     85
# C      79
# Name: count, dtype: int64

# %%
# visualize the employee position distribution using a pie chart
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
plt.suptitle("Employee Position Distribution")
position_count.plot(kind='pie', autopct='%1.1f%%', startangle=140, ax=axes[0])
position_count.plot(kind="bar", ax=axes[1])
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Q3. Identify the predominant age group among employees.

# %%
# predominant age group among employees.

da["Age"].describe()
# Out:
# count    458.000000
# mean      26.934498
# std        4.400128
# min       19.000000
# 25%       24.000000
# 50%       26.000000
# 75%       30.000000
# max       40.000000
# Name: Age, dtype: float64

# %%
# predominant age group among employees.
age_bins = [10, 20, 30, 40,50]
age_labels = ['10-19','20-29', '30-39', '40-49']
da['Age_Group'] = pd.cut(da['Age'], bins=age_bins, labels=age_labels, right=False)
age_group_count = da['Age_Group'].value_counts().sort_index()  
age_group_count
# Out:
# Age_Group
# 10-19      2
# 20-29    334
# 30-39    119
# 40-49      3
# Name: count, dtype: int64

# %%
#visualization of the age group distribution using a bar chart
plt.figure()
age_group_count.plot(kind="bar")
plt.title("Employee Count by Age Group")
plt.xlabel("Age Group"); plt.ylabel("Count")
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# ##### Q4. Discover which team and position have the highest salary expenditure.

# %%
# Discover which team and position have the highest salary expenditure.
salary_expenditure = da.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
highest_expenditure = salary_expenditure.loc[salary_expenditure['Salary'].idxmax()]    
highest_expenditure
# Out:
# Team        Los Angeles Lakers
# Position                    SF
# Salary              31866445.0
# Name: 67, dtype: object

# %%
salary_by_team = (
    df.groupby("Team", dropna=False)["Salary"]
      .sum(min_count=1)
      .fillna(0)
      .sort_values(ascending=False)
)
salary_by_position = (
    df.groupby("Position", dropna=False)["Salary"]
      .sum(min_count=1)
      .fillna(0)
      .sort_values(ascending=False)
)

print("Top-spend Team:", salary_by_team.index[0], int(salary_by_team.iloc[0]))
print("Top-spend Position:", salary_by_position.index[0], int(salary_by_position.iloc[0]))
# Out:
# Top-spend Team: Cleveland Cavaliers 106988689
# Top-spend Position: C 466377332

# %%
fig, axes = plt.subplots(1, 2, figsize=(12, 6))
salary_by_team.plot(kind="bar", ax=axes[0], color='skyblue', title='Total Salary by Team')
salary_by_position.plot(kind="bar", ax=axes[1], color='salmon', title='Total Salary by Position')
plt.tight_layout()  
plt.show()

# %%
da.describe()
# Out:
#            Number         Age      Height      Weight        Salary
# count  458.000000  458.000000  458.000000  458.000000  4.470000e+02
# mean    17.713974   26.934498  165.013100  221.543668  4.833970e+06
# std     15.966837    4.400128    8.874018   26.343200  5.226620e+06
# min      0.000000   19.000000  150.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  158.000000  200.000000  1.025210e+06
# 50%     13.000000   26.000000  164.000000  220.000000  2.836186e+06
# 75%     25.000000   30.000000  173.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  180.000000  307.000000  2.500000e+07

# %% [markdown]
# ##### Q5. Investigate if there's any correlation between age and salary, and represent it visually.

# %%
#Investigate if there's any correlation between age and salary, and represent it visually.
correlation = da[['Age', 'Salary']].dropna().corr()
correlation
# Out:
#              Age    Salary
# Age     1.000000  0.214009
# Salary  0.214009  1.000000

# %%
#visualization correlation between age and salary

plt.figure(figsize=(8, 6))
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Correlation between Age and Salary") 
plt.show()

# %%
age_salary = df[["Age", "Salary"]].dropna()
corr = age_salary["Age"].corr(age_salary["Salary"])
print("Pearson r (Age vs Salary):", round(corr, 3))

plt.figure()
plt.scatter(age_salary["Age"], age_salary["Salary"])
# Trendline
z = np.polyfit(age_salary["Age"], age_salary["Salary"], 1)
p = np.poly1d(z)
xs = np.linspace(age_salary["Age"].min(), age_salary["Age"].max(), 100)
plt.plot(xs, p(xs))
plt.title(f"Age vs Salary (r = {corr:.3f})")
plt.xlabel("Age"); plt.ylabel("Salary")
plt.tight_layout()
plt.show()
# Out:
# Pearson r (Age vs Salary): 0.214

# %% [markdown]
# <u><center><h2>DATA STORY</h></center></u>
#
# <H4>ABC Company — Employee Analysis Conclusion :</H4>
#
# **Dataset** contain 458 rows, 9 columns.
#
# **Preprocessing:**
#
#         - Replaced incorrect Height values
#         - filled Random integers [150, 180]
#         - Ensure Numerical values integrity and consistancy
#
# **Team Distribution:**
#
#         - The largest teams by headcount are New Orleans Pelicans serving  which together account for 4.1
#          of the employees
#         - The second larget teams by headcount are New Orleans Pelicans serving which together account for
#           3.93 of the employees
#         - Smaller teams include 3.06% of the entire teams
# **Positions:**
#
#         - The most common positions are SG This suggests staffing is concentrated in 102
#         - the lowest position serve C with 79 staffs
#
# **Age Profile:**
#
#         - The predominant age group is 20 to 29 . it consist 334 employees in this age catogary .
#           that means, this  comapny hiring youngers . and the leaders look like olders . and also they
#           provide  internship as well
# **Salary Expenditure:**
#
#         - Highest total salary by team is Los Angeles Lakers  and by position is SF with salary 31866445.0
#         - This concentration may reflect market rates or star talent; review alignment with performance.
#
# **Age–Salary Relationship:**
#
#         - Age salary is correlated each other if age is high the salary become high . that means high
#           expirence people get best market salary
#         - If the employee in his early stage of the career he will only get basic salary
#         - If age–salary link is weak, ensure pay progression tracks skill/impact over tenure.
